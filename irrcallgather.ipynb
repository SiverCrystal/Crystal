# %% [markdown]
# ### 콜금리 수집
# #### naver 콜 금리 지표 수집
# * https://finance.naver.com/marketindex/interestDailyQuote.nhn?marketindexCd=IRR_CALL&page=2

# %%
import requests
import sqlite3
from bs4 import BeautifulSoup
import datetime 
import wget
import html2text

# %%
pgno=1
mainurl=f'https://finance.naver.com/marketindex/interestDailyQuote.nhn?marketindexCd=IRR_CALL&page={pgno}'

# %%
dbname='bok.db'

def sqexe(s,data):
    with sqlite3.connect(dbname) as conn:
        cur=conn.cursor()
        result=cur.execute(s,data).fetchall()
        conn.commit()
        cur.close()
    return result

# %%
def mkirrTable(day,callirr):
    sql="select day from irrcall where day=?"
    data=[day]
    res=sqexe(sql,data)
#print('result:',res)

    if (res):
        print('duplicate')
    else:            
        sql="insert into irrcall (day,irr) values(?,?)"
        data=[day,irr]
        res=sqexe(sql,data)da

# %%
url=mainurl
preurl='http://www.naver.com'

#pdf_folder='pdfs/'

def IrGather(fr=1,to=10):
    for i in range(fr,to):
        ur=f'https://finance.naver.com/marketindex/interestDailyQuote.nhn?marketindexCd=IRR_CALL&page={pgno}'
        urlGet(ur)
        
def urlGet(url):
    page=requests.get(url)
    soup = BeautifulSoup(page.content,'html.parser')
    rows=soup.select('table>tbody>tr')
    for r in rows:
        day=r.select('td')[0].get_text().strip().replace('.','')
        endp=r.select('td')[1].get_text().strip()
        print(day,endp)
        mkirrTable(day,endp)
        print('*'*50)

IrGather(100,200)
# Out:
# 20190821 1.51
# duplicate
# **************************************************
# 20190820 1.51
# duplicate
# **************************************************
# 20190819 1.51
# duplicate
# **************************************************
# 20190816 1.52
# duplicate
# **************************************************
# 20190814 1.52
# duplicate
# **************************************************
# 20190813 1.52
# duplicate
# **************************************************
# 20190812 1.52
# duplicate
# **************************************************
# 20190821 1.51
# duplicate
# **************************************************
# 20190820 1.51
# duplicate
# **************************************************
# 20190819 1.51
# duplicate
# **************************************************
# 20190816 1.52
# duplicate
# **************************************************
# 20190814 1.52
# duplicate
# **************************************************
# 20190813 1.52
# duplicate
# ...

# %%
def IrGather()
